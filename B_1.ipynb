# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dataset_Facebook.csv',sep=";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data=df.iloc[0:100]

# %%
data
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0             139441   Photo         2          12             4          3  \
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# ..               ...     ...       ...         ...           ...        ...
# 95            137059   Photo         3          10             6         10
# 96            137059   Photo         1          10             6          3
# 97            137059   Photo         2          10             5         11
# 98            137020  Status         2          10             5          3
# 99            137020   Photo         1          10             4         10
#
# ...

# %%
data1=df.iloc[100:200]

# %%
data1
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 100            137020  Photo         1          10             4          9  \
# 101            137020  Photo         2          10             4          3
# 102            137020  Photo         3          10             3         10
# 103            137020  Photo         1          10             3          4
# 104            137020  Photo         1          10             2         11
# ..                ...    ...       ...         ...           ...        ...
# 195            133594  Photo         2           8             6         10
# 196            133594  Photo         1           8             6          8
# 197            133594  Photo         2           8             5         13
# 198            133451  Photo         1           8             4          9
# 199            132817  Photo         3           8             4         10
#
# ...

# %%
data2=df.iloc[200:300]

# %%
data2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 200            132817   Photo         2           8             4          3  \
# 201            132817   Photo         1           8             3          9
# 202            132817  Status         2           8             3          2
# 203            132817   Photo         3           8             2         10
# 204            132817   Photo         3           8             2          3
# ..                ...     ...       ...         ...           ...        ...
# 295            125612   Photo         1           6             2          2
# 296            125612   Photo         3           6             1         14
# 297            125612   Photo         3           6             1          3
# 298            125612   Photo         2           6             7         11
# 299            124940   Photo         1           6             7          4
#
# ...

# %%
data3=df.iloc[300:400]

# %%
data3
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 300            124940  Photo         2           6             6          9  \
# 301            124940  Photo         3           6             6          2
# 302            124940  Photo         1           6             5         13
# 303            124940  Photo         3           6             5          3
# 304            124940  Photo         1           6             4         12
# ..                ...    ...       ...         ...           ...        ...
# 395            107907  Photo         1           4             6          9
# 396            107907  Photo         3           4             6          3
# 397            107907  Photo         1           4             5          9
# 398            107907  Photo         3           4             5          3
# 399            107907  Photo         3           4             4         13
#
# ...

# %%
data4=df.iloc[400:500]

# %%
data4
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 400            107907  Photo         3           4             4          5  \
# 401            107907  Photo         1           4             3         13
# 402            107907  Photo         1           4             3          4
# 403            107907   Link         1           4             2          6
# 404            107907  Photo         3           4             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
meregeddata=pd.concat([data,data1,data2,data3,data4],axis=0)

# %%
meregeddata
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
sorteddata=df.sort_values(by=['Post Hour'])

# %%
sorteddata
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 154            135713  Photo         2          10             4          1  \
# 333            119198  Photo         3           5             2          1
# 212            132201  Photo         2           8             5          1
# 258            129600  Photo         2           7             3          1
# 346            117764  Photo         3           5             7          2
# ..                ...    ...       ...         ...           ...        ...
# 426            100732  Photo         1           3             7         18
# 422            102112  Photo         1           3             1         19
# 381            109670  Photo         3           4             6         20
# 287            126141  Photo         1           6             4         22
# 230            131630  Photo         3           7             2         23
#
# ...

# %%
df['Post Hour']
# Out:
# 0       3
# 1      10
# 2       3
# 3      10
# 4       3
#        ..
# 495     2
# 496     8
# 497     2
# 498    11
# 499     4
# Name: Post Hour, Length: 500, dtype: int64

# %%
transposeddata=df.transpose()

# %%
transposeddata
# Out:
#                                                        0       1       2
# Page total likes                                    139441  139441  139441  \
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
result=pd.pivot_table(df,index=['Type','Paid'],values='comment')

# %%
result
# Out:
#                comment
# Type   Paid
# Link   0.0    2.375000
#        1.0    4.000000
# Photo  0.0    6.598039
#        1.0    9.857143
# Status 0.0    7.200000
#        1.0   14.900000
# Video  0.0   10.333333
#        1.0   13.750000

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...
